# %%
import pandas as pd
from collections import defaultdict
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns
from collections import Counter
from sklearn.metrics import multilabel_confusion_matrix

# %%
dfx = pd.read_csv("dfx.csv")

# %%
dfx.head()
# Out:
#   Unnamed: 0      RERE    RNF165  CD049690  BC033982      PHF7      CIDEA  \
# 0    MB-0362  8.676978  6.075331  5.453928  4.994525  5.838270   6.397503
# 1    MB-0346  9.653589  6.687887  5.454185  5.346010  5.600876   5.246319
# 2    MB-0386  9.033589  5.910885  5.501577  5.247467  6.030718  10.111816
# 3    MB-0574  8.814855  5.628740  5.471941  5.316523  5.849428   6.116868
# 4    MB-0503  9.274265  5.908698  5.531743  5.244094  5.964661   7.828171
#
#       PAPD4  AI082173   SLC17A3  ...  DA110839    FAM71A  \
# 0  7.906217  5.259461  5.702379  ...  5.251843  5.049591
# 1  8.267256  5.380069  5.521794  ...  5.450611  5.316790
# 2  7.959291  5.262024  5.689533  ...  5.235394  5.461617
# 3  9.206376  5.396576  5.439130  ...  5.091927  5.227130
# 4  8.706646  5.167213  5.417484  ...  5.315224  5.027476
#
#                Cancer Type Detailed  ER Status  HER2 Status  \
# 0  Breast Invasive Ductal Carcinoma   Positive     Negative
# 1  Breast Invasive Ductal Carcinoma   Negative     Positive
# 2  Breast Invasive Ductal Carcinoma   Positive     Negative
# 3  Breast Invasive Ductal Carcinoma   Positive     Negative
# 4  Breast Invasive Ductal Carcinoma   Positive     Negative
#
#    Neoplasm Histologic Grade  Oncotree Code  PR Status  Tumor Size  \
# 0                        2.0            IDC   Positive        18.0
# 1                        3.0            IDC   Negative        16.0
# 2                        3.0            IDC   Positive        15.0
# 3                        3.0            IDC   Positive        21.0
# 4                        2.0            IDC   Positive        23.0
#
#    Tumor Stage
# 0          2.0
# 1          2.0
# 2          3.0
# 3          2.0
# 4          2.0
#
# [5 rows x 24377 columns]

# %%
dfx_only_pr = dfx.drop(['Unnamed: 0','Cancer Type Detailed','ER Status','HER2 Status','Neoplasm Histologic Grade','Tumor Stage','Oncotree Code','Tumor Size'],axis=1)

# %%
dfx_only_pr.head()
#Where OncoTreeCode is NA
# dfx_only_onc = dfx_only_onc[np.isfinite(dfx_only_onc['Oncotree Code'])]
# dfx_only_onc['Oncotree Code'].isnull().values.any()
dfx_only_pr = dfx_only_pr[pd.notnull(dfx_only_pr['PR Status'])]
dfx_only_pr['PR Status'].isnull().values.any()
# Out:
# False

# %%
dfx_only_pr.head()
# Out:
#        RERE    RNF165  CD049690  BC033982      PHF7      CIDEA     PAPD4  \
# 0  8.676978  6.075331  5.453928  4.994525  5.838270   6.397503  7.906217
# 1  9.653589  6.687887  5.454185  5.346010  5.600876   5.246319  8.267256
# 2  9.033589  5.910885  5.501577  5.247467  6.030718  10.111816  7.959291
# 3  8.814855  5.628740  5.471941  5.316523  5.849428   6.116868  9.206376
# 4  9.274265  5.908698  5.531743  5.244094  5.964661   7.828171  8.706646
#
#    AI082173   SLC17A3       SDS  ...  BX107598    UGCGL1     VPS72     CSMD3  \
# 1896  7.601081  5.345468  6.193474  5.234638  6.166514  5.485667  5.820858
# 1897  8.363610  5.350640  6.437007  5.330035  7.342794  5.369609  5.390758
# 1898  8.040024  5.456862  6.269748  5.337776  7.288315  5.359223  5.253696
# 1899  7.560101  5.397010  7.088676  5.216496  7.248336  5.544276  5.436415
# 1900  7.941895  5.415928  6.110477  5.427567  7.596215  5.405179  5.094339
# 1901  7.866579  5.242482  6.316304  4.977467  6.620605  5.631662  5.350708
# 1902  7.752503  5.320171  7.594277  5.690294  7.437116  5.590516  5.329209
#
# [1903 rows x 24368 columns]

# %%
Y
# Out:
# 0       Positive
# 1       Negative
# 2       Positive
# 3       Positive
# 4       Positive
# 5       Negative
# 6       Negative
# 7       Positive
# 8       Negative
# 9       Negative
# 10      Negative
# 11      Negative
# 12      Positive
# 13      Positive
# 14      Positive
# 15      Positive
# 16      Negative
# 17      Negative
# 18      Positive
# 19      Positive
# 20      Positive
# 21      Negative
# 22      Negative
# 23      Negative
# 24      Negative
# 25      Negative
# 26      Negative
# 27      Positive
# 28      Negative
# 29      Negative
#           ...
# 1873    Negative
# 1874    Negative
# 1875    Negative
# 1876    Negative
# 1877    Positive
# 1878    Negative
# 1879    Negative
# 1880    Negative
# 1881    Negative
# 1882    Positive
# 1883    Positive
# 1884    Negative
# 1885    Positive
# 1886    Positive
# 1887    Negative
# 1888    Positive
# 1889    Positive
# 1890    Positive
# 1891    Negative
# 1892    Positive
# 1893    Positive
# 1894    Positive
# 1895    Positive
# 1896    Negative
# 1897    Positive
# 1898    Negative
# 1899    Positive
# 1900    Negative
# 1901    Positive
# 1902    Positive
# Name: PR Status, Length: 1903, dtype: object

# %% [markdown]
# Finding number of unique values

# %%
np.unique(Y, return_counts=True)
# Out:
# (array(['Negative', 'Positive'], dtype=object),
#  array([ 894, 1009], dtype=int64))

# %% [markdown]
# Imputing missing values

# %%
from sklearn.impute import SimpleImputer
imp = SimpleImputer(missing_values=np.nan, strategy='mean')
X_impu = imp.fit_transform(X)
X_impu = pd.DataFrame(X_impu, columns=X.columns)

# %%
X_impu
# Out:
#           RERE    RNF165  CD049690  BC033982      PHF7      CIDEA     PAPD4  \
# 0     8.676978  6.075331  5.453928  4.994525  5.838270   6.397503  7.906217
# 1     9.653589  6.687887  5.454185  5.346010  5.600876   5.246319  8.267256
# 2     9.033589  5.910885  5.501577  5.247467  6.030718  10.111816  7.959291
# 3     8.814855  5.628740  5.471941  5.316523  5.849428   6.116868  9.206376
# 4     9.274265  5.908698  5.531743  5.244094  5.964661   7.828171  8.706646
# 5     9.286585  6.206729  5.372668  5.167365  5.783374   8.744149  8.518929
# 6     8.437347  6.095592  5.693519  5.189106  5.737572   5.480091  7.478413
# 7     8.569973  6.383530  5.401276  5.416517  5.923928   5.671577  8.410583
# 8     8.892102  5.773691  5.567946  5.339133  5.902223   5.509498  7.779545
# 9     8.922748  6.461321  5.410957  5.389980  5.536764   7.196945  8.385897
# 10    9.053967  6.093467  5.251529  5.157996  5.855084   9.286315  8.396757
# 11    8.293003  6.725088  5.397237  5.125467  5.659488   7.176816  8.177391
# 1884  8.218732  5.419116  6.194527  5.236807  7.745932  5.383784  5.147187
# 1885  8.140274  5.361480  6.066257  5.328245  7.219604  5.351943  5.094093
# 1886  7.326404  5.477335  6.147096  5.508123  6.415231  5.294654  5.528779
# 1887  7.914609  5.446034  5.961906  5.283811  7.099823  5.207231  5.610520
# 1888  8.186021  5.232414  6.412721  5.326191  6.357439  5.325848  5.367991
# 1889  7.965642  5.210116  6.525927  5.212181  6.146858  5.638097  5.658308
# 1890  8.283618  5.284983  6.295876  5.656053  6.798448  5.469277  5.218734
# 1891  8.913091  5.364518  7.494786  5.531941  7.994077  5.300824  5.309289
# 1892  7.627360  5.427737  6.141820  5.345844  6.741674  5.392203  5.424984
# 1893  7.751008  5.445386  6.111693  5.304611  6.668100  5.583404  5.360993
# 1894  7.823506  5.221058  6.180190  4.970910  6.580473  5.222982  5.200058
# 1895  7.588018  5.119401  6.026150  5.326566  5.927223  5.487438  5.653923
# 1896  7.601081  5.345468  6.193474  5.234638  6.166514  5.485667  5.820858
# 1897  8.363610  5.350640  6.437007  5.330035  7.342794  5.369609  5.390758
# 1898  8.040024  5.456862  6.269748  5.337776  7.288315  5.359223  5.253696
# 1899  7.560101  5.397010  7.088676  5.216496  7.248336  5.544276  5.436415
# 1900  7.941895  5.415928  6.110477  5.427567  7.596215  5.405179  5.094339
# 1901  7.866579  5.242482  6.316304  4.977467  6.620605  5.631662  5.350708
# 1902  7.752503  5.320171  7.594277  5.690294  7.437116  5.590516  5.329209
#
# [1903 rows x 24368 columns]

# %% [markdown]
# Feature Selection

# %% [markdown]
# # Using 2000 features

# %%
from sklearn.feature_selection import chi2
from sklearn.feature_selection import SelectKBest
selector = SelectKBest(chi2, k=2000)
selector.fit(X_impu, Y)
cols = selector.get_support(indices=True)
X_new = X_impu.iloc[:,cols]
# X_new

# %%
print("the shape of new data is: ",X_new.shape)
# Out:
# the shape of new data is:  (1903, 2000)

# %% [markdown]
# Resampling

# %%
from imblearn.over_sampling import SMOTE 
sm = SMOTE(random_state=42,k_neighbors=3, sampling_strategy='auto')
X_s, y_s = sm.fit_resample(X_new, Y)
print('Resampled dataset shape after running SMOTE algorithm for Data Oversampling %s' % Counter(y_s))
# Out:
# Resampled dataset shape after running SMOTE algorithm for Data Oversampling Counter({'Negative': 1009, 'Positive': 1009})

# %% [markdown]
# Training Testing Split

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error

X_train, X_test, y_train, y_test = train_test_split(X_s, y_s, test_size=0.2)
print ("the shape of training data is ",X_train.shape, y_train.shape)
print ("the shape of testing data is ",X_test.shape, y_test.shape)
# Out:
# the shape of training data is  (1614, 2000) (1614,)
# the shape of testing data is  (404, 2000) (404,)

# %%
from sklearn.neural_network import MLPClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.gaussian_process import GaussianProcessClassifier
from sklearn.gaussian_process.kernels import RBF
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.discriminant_analysis import QuadraticDiscriminantAnalysis
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import label_binarize
from sklearn.multiclass import OneVsRestClassifier
from sklearn.metrics import roc_curve, auc

# %%
clf = SVC(kernel="linear", C=0.025)
#79 before
clf.fit(X_train, y_train)
y_pred = clf.predict(X_test)
print(multilabel_confusion_matrix(y_test, y_pred, labels=['Positive', 'Negative']))
score = clf.score(X_test, y_test)

print(score)
# Out:
# [[[174  22]
#   [ 23 185]]
#
#  [[185  23]
#   [ 22 174]]]
# 0.8886138613861386

# %%
clf = SVC(kernel='rbf', gamma=0.0006)
 #81.21 before, 0.715 0.05 gamma, 99.006 0.001 gamma
clf.fit(X_train, y_train)
y_pred = clf.predict(X_test)
print(multilabel_confusion_matrix(y_test, y_pred, labels=['Positive', 'Negative']))
score = clf.score(X_test, y_test)
print(score)
# Out:
# [[[178  18]
#   [ 18 190]]
#
#  [[190  18]
#   [ 18 178]]]
# 0.9108910891089109

# %%
clf = LogisticRegression()

clf.fit(X_train, y_train)
y_pred = clf.predict(X_test)
print(multilabel_confusion_matrix(y_test, y_pred, labels=['Positive', 'Negative']))
score = clf.score(X_test, y_test)
print(score)
# Out:
# [[[175  21]
#   [ 23 185]]
#
#  [[185  23]
#   [ 21 175]]]
# 0.8910891089108911
# c:\users\nimis\appdata\local\programs\python\python35\lib\site-packages\sklearn\linear_model\_logistic.py:939: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html.
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)

# %%
clf = GaussianNB()
#0.568 before
clf.fit(X_train, y_train)
y_pred = clf.predict(X_test)
print(multilabel_confusion_matrix(y_test, y_pred, labels=['Positive', 'Negative']))
score = clf.score(X_test, y_test)
print(score)
# Out:
# [[[129  67]
#   [ 27 181]]
#
#  [[181  27]
#   [ 67 129]]]
# 0.7673267326732673

# %% [markdown]
# ### Ensemble

# %%
from sklearn.ensemble import VotingClassifier
from sklearn.ensemble import BaggingClassifier, ExtraTreesClassifier, RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import AdaBoostClassifier

# %%
lr = LogisticRegression(max_iter = 20)
svm_linear = SVC(kernel='linear',C=0.025)
svm = SVC(kernel = 'rbf', gamma=0.001)
evc = VotingClassifier( estimators= [('svm_linear',svm_linear),('lr',lr),('svm',svm)], voting = 'hard')
evc.fit(X_train,y_train)
evc.score(X_test, y_test)
# Out:
# c:\users\nimis\appdata\local\programs\python\python35\lib\site-packages\sklearn\linear_model\_logistic.py:939: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html.
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# 0.8985148514851485

# %%
y_pred = evc.predict(X_test)
print(multilabel_confusion_matrix(y_test, y_pred, labels=['Positive', 'Negative']))
# Out:
# [[[176  20]
#   [ 21 187]]
#
#  [[187  21]
#   [ 20 176]]]

# %% [markdown]
# # Using 5000 features

# %%
from sklearn.feature_selection import chi2
from sklearn.feature_selection import SelectKBest
selector = SelectKBest(chi2, k=5000)
selector.fit(X_impu, Y)
cols = selector.get_support(indices=True)
X_new = X_impu.iloc[:,cols]

# %%
print("the shape of new data is: ",X_new.shape)
# Out:
# the shape of new data is:  (1903, 5000)

# %% [markdown]
# Resampling

# %%
from imblearn.over_sampling import SMOTE 
sm = SMOTE(random_state=42,k_neighbors=3, sampling_strategy='auto')
X_s, y_s = sm.fit_resample(X_new, Y)
print('Resampled dataset shape after running SMOTE algorithm for Data Oversampling %s' % Counter(y_s))
dfffff = pd.DataFrame(X_s)
dfffff = pd.concat([dfffff,y_s],axis=1)
sns.countplot(dfffff['PR Status'])
# Out:
# Resampled dataset shape after running SMOTE algorithm for Data Oversampling Counter({'Positive': 1009, 'Negative': 1009})

# %%
sns.countplot(dfx['PR Status'])

# %% [markdown]
# Training Testing Split

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error

X_train, X_test, y_train, y_test = train_test_split(X_s, y_s, test_size=0.2)
print ("the shape of training data is ",X_train.shape, y_train.shape)
print ("the shape of testing data is ",X_test.shape, y_test.shape)
# Out:
# the shape of training data is  (1614, 5000) (1614,)
# the shape of testing data is  (404, 5000) (404,)

# %%
from sklearn.neural_network import MLPClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.gaussian_process import GaussianProcessClassifier
from sklearn.gaussian_process.kernels import RBF
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.discriminant_analysis import QuadraticDiscriminantAnalysis
from sklearn.linear_model import LogisticRegression

# %%
clf = RandomForestClassifier()
clf.fit(X_train, y_train)
y_pred = clf.predict(X_test)
# importances = clf.feature_importances_

#print feature importances
feature_importances = zip(cols, clf.feature_importances_)


print(multilabel_confusion_matrix(y_test, y_pred))
score = clf.score(X_test, y_test)
print(score)
# Out:
# [[[201  14]
#   [ 24 165]]
#
#  [[165  24]
#   [ 14 201]]]
# 0.905940594059406

# %%
feature_importances = zip(cols, clf.feature_importances_)
feature_importances = sorted(feature_importances, key = lambda x:x[1],reverse = True)
for x, y in feature_importances[:10]:
    print (dfx.columns[x],y)
# Out:
# AU311496 0.07829942152477956
# CACNA2D4 0.012808249005711163
# FAM108B1 0.011365707214941553
# MTRR 0.01031901370170994
# AF508911 0.008520409922655748
# FBXO5 0.008185276013213456
# LOC441052 0.006657575428751339
# AW469525 0.006480964442012457
# KLHL22 0.006423008535749142
# ITGB1BP2 0.006138838976772227

# %%
clf = SVC(kernel="linear",C=0.025)
#79 before
clf.fit(X_train, y_train)
y_pred = clf.predict(X_test)
# print(clf.feature_importances_)
print(multilabel_confusion_matrix(y_test, y_pred, labels=['Positive', 'Negative']))
score = clf.score(X_test, y_test)
print(score)
# Out:
# [[[162  27]
#   [ 24 191]]
#
#  [[191  24]
#   [ 27 162]]]
# 0.8737623762376238

# %%
clf = SVC(kernel='rbf', gamma=0.0003) #0.8811
clf.fit(X_train, y_train)
y_pred = clf.predict(X_test)
print(multilabel_confusion_matrix(y_test, y_pred, labels=['Positive', 'Negative']))
score = clf.score(X_test, y_test)
print(score)
# Out:
# [[[161  28]
#   [ 20 195]]
#
#  [[195  20]
#   [ 28 161]]]
# 0.8811881188118812

# %%
clf = LogisticRegression(max_iter=500)

clf.fit(X_train, y_train)
score = clf.score(X_test, y_test)
y_pred = clf.predict(X_test)
print(multilabel_confusion_matrix(y_test, y_pred, labels=['Positive', 'Negative']))
print(score)
# Out:
# [[[164  25]
#   [ 23 192]]
#
#  [[192  23]
#   [ 25 164]]]
# 0.8811881188118812
# c:\users\nimis\appdata\local\programs\python\python35\lib\site-packages\sklearn\linear_model\_logistic.py:939: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html.
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)

# %%
clf = GaussianNB()
#0.568 before
clf.fit(X_train, y_train)
y_pred = clf.predict(X_test)
print(multilabel_confusion_matrix(y_test, y_pred, labels=['Positive', 'Negative']))
score = clf.score(X_test, y_test)

print(score)
# Out:
# [[[136  77]
#   [ 24 167]]
#
#  [[167  24]
#   [ 77 136]]]
# 0.75

# %% [markdown]
# ### Ensemble

# %%
from sklearn.ensemble import VotingClassifier
from sklearn.ensemble import BaggingClassifier, ExtraTreesClassifier, RandomForestClassifier, AdaBoostClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier

# %%
lr = LogisticRegression(max_iter = 20)
rf = RandomForestClassifier()

svm_linear = SVC(kernel='linear')
svm = SVC(kernel = 'rbf', gamma=0.0003)
evc = VotingClassifier( estimators= [('svm_linear',svm_linear),('lr',lr),('svm',svm),('rf',rf)], voting = 'hard')
evc.fit(X_train,y_train)
evc.score(X_test, y_test)
# Out:
# c:\users\nimis\appdata\local\programs\python\python35\lib\site-packages\sklearn\linear_model\_logistic.py:939: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html.
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# 0.8960396039603961

# %%
y_pred = evc.predict(X_test)
print(multilabel_confusion_matrix(y_test, y_pred, labels=['Positive','Negative']))
# Out:
# [[[184  23]
#   [ 18 179]]
#
#  [[179  18]
#   [ 23 184]]]

# %% [markdown]
# # Dimensionality Reduction and Plot

# %%
from sklearn.decomposition import KernelPCA,PCA
pca = PCA(n_components=3)
X_reduced = pca.fit_transform(X_impu)
X_reduced.shape
# Out:
# (1903, 3)

# %%
y_num = Y.apply(['Positive','Negative'].index)

# %%
x_nen=pd.DataFrame(data=X_reduced[0:,0:],index=[i for i in range(X_reduced.shape[0])],columns=['f'+str(i) for i in range(X_reduced.shape[1])])

# %%
x_nen['y'] = y_num

# %%
idcs = x_nen[x_nen.y == 0]
ilcs = x_nen[x_nen.y == 1]

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

fig = plt.figure()
ax = fig.add_subplot(111,projection='3d')
ax.scatter(idcs.iloc[:,0],idcs.iloc[:,1],idcs.iloc[:,2],c='r',marker='^',label='Positive')
ax.scatter(ilcs.iloc[:,0],ilcs.iloc[:,1],ilcs.iloc[:,2],c='green',marker='v',label='Negative')

ax.view_init(40, 20)
ax.legend()
plt.savefig('PR PCA.png')

# %% [markdown]
# # Using resampled data

# %%
from sklearn.decomposition import KernelPCA,PCA
pca = PCA(n_components=3)
X_reduced = pca.fit_transform(X_s)
X_reduced.shape
# Out:
# (2018, 3)

# %%
y_num = y_s.apply(['Positive','Negative'].index)

# %%
x_nen=pd.DataFrame(data=X_reduced[0:,0:],index=[i for i in range(X_reduced.shape[0])],columns=['f'+str(i) for i in range(X_reduced.shape[1])])

# %%
x_nen['y'] = y_num

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

fig = plt.figure()
ax = fig.add_subplot(111,projection='3d')
ax.scatter(idcs.iloc[:,0],idcs.iloc[:,1],idcs.iloc[:,2],c='r',marker='^',label='Positive')
ax.scatter(ilcs.iloc[:,0],ilcs.iloc[:,1],ilcs.iloc[:,2],c='green',marker='v',label='Negative')


ax.view_init(40, 20)

ax.legend(scatterpoints=1,
           loc='lower left',
           ncol=3,
           fontsize=8)
plt.savefig('PR SMOTE PCA.png')
